# %%
import pandas as pd

# %%
cana_df = pd.read_csv(
    "/home/kenu/Documents/KBTU 2022/Data Visualization/for_final/data/total_canada_kz.csv",
    encoding="utf-8")
cana_df.head()
# cana_df = cana_df.groupby('year').sum().reset_index("year")
# cana_df["year"]= cana_df["year"].astype(str)
# cana_df.to_csv("total_canada_kz")
cana_df["kazakhstan"] = cana_df["kazakhstan"].apply(lambda x: round(x,2))
cana_df["canada"] = cana_df["canada"].apply(lambda x: round(x,2))
cana_df["year"] = cana_df["year"].apply(lambda x: str(int(x)))

cana_df.to_csv("/home/kenu/Documents/KBTU 2022/Data Visualization/for_final/data/total_canada_kz.csv", index=False)

# %%
df.groupby('Courses').sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/kenu/Documents/KBTU 2022/Data Visualization/for_final/python/fixing and convertation.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/kenu/Documents/KBTU%202022/Data%20Visualization/for_final/python/fixing%20and%20convertation.ipynb#ch0000017?line=0'>1</a> df.groupby('Courses').sum()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import numpy as np


df = pd.read_excel(
    "/home/kenu/Documents/KBTU 2022/Data Visualization/for_final/final_data/real_gross_100_per_hect_wheat.xlsx", index_col=0)

# print(df.head())
for column in df.columns:
    print(column)
    print(df[column])
    df[column] = df[column].replace("-", 0)
    df[column] = df[column].apply(lambda x: round(float(x), 2))

    # >>> df.drop(index=('falcon', 'weight'))
df_t = df.T
df_t["Акмолинская"] = df_t["г. Нур-Султан"] + df_t["Акмолинская"]
df_t["Алматинская"] = df_t["г. Алматы"] + df_t["Алматинская"]
df_t["Туркестанская"] = df_t["г. Шымкент"] + \
    df_t["Туркестанская"] + df_t["Южно-Казахстанская"]


df = df_t.T
df = df.drop(labels=["г. Алматы", "г. Нур-Султан",
             "г. Шымкент", "Южно-Казахстанская"], axis=0)


df_t = df.T
column_re = {'Республика Казахстан': 'Republic of Kazakhstan', 'Акмолинская': 'Aqmola',
             "Актюбинская": "Aqtöbe", "Алматинская": "Almaty", "Атырауская": "Atyrau",
             "Западно-Казахстанская": "West Kazakhstan", "Жамбылская": "Zhambyl",
             "Карагандинская": "Qaraghandy", "Костанайская": "Qostanay", "Мангыстауская": "Mangghystau",
             "Кызылординская": "Qyzylorda", "Туркестанская": "Türkistan",
             "Павлодарская": "Pavlodar", "Северо-Казахстанская": "North Kazakhstan",
             "Восточно-Казахстанская": "East Kazakhstan"}
df_t.rename(columns=column_re, inplace=True)

# print("\n".join([ f"d['{value}'] = +d['{value}'];" for key, value in column_re.items()]))
print("\n".join([ f"'{value}'," for key, value in column_re.items()]))
# print(df_t)
df_t.to_csv("real_gross_100_per_hect_wheat.csv")
# Out:
# 2004
# region
# Республика Казахстан       8.4
# Акмолинская                7.1
# Актюбинская                5.3
# Алматинская               17.4
# Атырауская                 4.0
# Западно-Казахстанская      5.6
# Жамбылская                16.9
# Карагандинская             6.9
# Костанайская               8.0
# Кызылординская            14.4
# Южно-Казахстанская        20.2
# Туркестанская                -
# Павлодарская               6.5
# Северо-Казахстанская       9.4
# Восточно-Казахстанская    11.6
# г. Нур-Султан                -
# г. Алматы                    -
# г. Шымкент                   -
# Name: 2004, dtype: object
# 2005
# region
# Республика Казахстан       9.5
# Акмолинская                8.3
# Актюбинская                4.7
# Алматинская               17.0
# Атырауская                 1.3
# Западно-Казахстанская      3.9
# Жамбылская                15.5
# Карагандинская             3.9
# Костанайская              10.4
# Кызылординская            13.4
# ...

# %%
a = "/home/kenu/Documents/KBTU 2022/Data Visualization/for_final/final_data/real_gross_100_per_hect_wheat_rice_legumes.xlsx"
df = pd.read_excel(a, index_col=0)
df
# Out:
#                         2004  2005  2006  2007  2008  2009  2010  2011  2012  \
# Республика Казахстан     8.8    10  11.7  13.3  10.1  12.6     8  16.9   8.6
# Акмолинская              7.1   8.5   9.6  11.6   7.5  11.2   5.2  15.6     7
# Актюбинская              5.3   4.7   2.9   7.8   8.5   6.3   2.4   7.5   2.9
# Алматинская             20.4  19.7  19.8  22.2  16.2  25.6  22.7    24  23.4
# Атырауская               3.1   1.4     1   1.3   6.5   0.8     1   7.7   2.3
# Западно-Казахстанская    5.7   3.9   6.1   8.5  13.3   5.4   4.2   9.7   5.4
# Жамбылская                18  16.6  11.8    13   8.3    24  16.4  17.4    11
# Карагандинская           6.8   3.9   6.3   8.1   5.7   7.9   4.5  10.8   6.5
# Костанайская             7.9  10.5  13.4    15  11.5  11.1   7.3  18.4   6.1
# Кызылординская            32  30.7  30.4  31.1  30.7  33.5  38.5  34.7  34.6
# Южно-Казахстанская      21.3  16.8  14.6    17  11.6  21.2  17.6    17  15.4
# ...

# %%
for column in df.columns:
    df[column] = df[column].apply(lambda x: 0 if x=="-" else round(x, 2))
    df[column] = df[column].apply(lambda x: round(x, 2))

# %%
for column in df.columns:
    df[column] = df[column].apply(lambda x: 0 if x == "-" else round(x, 2))
    df[column] = df[column].apply(lambda x: round(x, 2))

df_t = df.T
try:
    df_t["Акмолинская"] = df_t["г.Астана"] + df_t["Акмолинская"]
except:
    df_t["Акмолинская"] = df_t["г. Нур-Султан"] + df_t["Акмолинская"]
    

# df_t["Алматинская"] = df_t["г.Алматы"] + df_t["Алматинская"]
df_t["Алматинская"] = df_t["г. Алматы"] + df_t["Алматинская"]
# df_t["Туркестанская"] = df_t["г.Шымкент"] + df_t["Туркестанская"] + df_t["Южно-Казахстанская"]
df_t["Туркестанская"] = df_t["г. Шымкент"] + df_t["Туркестанская"] + df_t["Южно-Казахстанская"]


df = df_t.T
try:
    df = df.drop(labels=["г.Астана"], axis=0)
except:
    df = df.drop(labels=["г. Нур-Султан"], axis=0)

    
# df = df.drop(labels=["г.Алматы", "г.Шымкент","Южно-Казахстанская"], axis=0)
df = df.drop(labels=["г. Алматы", "г. Шымкент","Южно-Казахстанская"], axis=0)


df_t = df.T

column_re = {'Республика Казахстан': 'Republic of Kazakhstan', 'Акмолинская': 'Aqmola',
                   "Актюбинская": "Aqtöbe", "Алматинская": "Almaty", "Атырауская": "Atyrau",
                   "Западно-Казахстанская": "West Kazakhstan", "Жамбылская": "Zhambyl",
                   "Карагандинская": "Qaraghandy", "Костанайская": "Qostanay", "Мангыстауская": "Mangghystau",
                   "Кызылординская": "Qyzylorda", "Туркестанская": "Türkistan",
                   "Павлодарская": "Pavlodar", "Северо-Казахстанская": "North Kazakhstan",
                   "Восточно-Казахстанская": "East Kazakhstan"}
df_t.rename(columns=column_re, inplace=True)

df_t.to_csv("100_rice_wheat_legumes.csv")

# %%
for column in df.columns:
    df[column] = df[column].apply(lambda x: 0 if x == "-" else round(x, 2))
    df[column] = df[column].apply(lambda x: round(x, 2))

df_t = df.T
try:
    df_t["Акмолинская"] = df_t["г.Астана"] + df_t["Акмолинская"]
except:
    pass
    df_t["Акмолинская"] = df_t["г. Нур-Султан"] + df_t["Акмолинская"]
    

# df_t["Алматинская"] = df_t["г.Алматы"] + df_t["Алматинская"]
df_t["Алматинская"] = df_t["г. Алматы"] + df_t["Алматинская"]
# df_t["Туркестанская"] = df_t["г.Шымкент"] + df_t["Туркестанская"] + df_t["Южно-Казахстанская"]
df_t["Туркестанская"] = df_t["г. Шымкент"] + df_t["Туркестанская"] + df_t["Южно-Казахстанская"]


df = df_t.T
try:
    df = df.drop(labels=["г.Астана"], axis=0)
except:
    df = df.drop(labels=["г. Нур-Султан"], axis=0)

    
# df = df.drop(labels=["г.Алматы", "г.Шымкент","Южно-Казахстанская"], axis=0)
df = df.drop(labels=["г. Алматы", "г. Шымкент","Южно-Казахстанская"], axis=0)


df_t = df.T
column_re = {'Республика Казахстан': 'Republic of Kazakhstan', 'Акмолинская': 'Aqmola',
                   "Актюбинская": "Aqtöbe", "Алматинская": "Almaty", "Атырауская": "Atyrau",
                   "Западно-Казахстанская": "West Kazakhstan", "Жамбылская": "Zhambyl",
                   "Карагандинская": "Qaraghandy", "Костанайская": "Qostanay", "Мангыстауская": "Mangghystau",
                   "Кызылординская": "Qyzylorda", "Туркестанская": "Türkistan",
                   "Павлодарская": "Pavlodar", "Северо-Казахстанская": "North Kazakhstan",
                   "Восточно-Казахстанская": "East Kazakhstan"}
df_t.rename(columns=column_re, inplace=True)
df=df_t.T
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/kenu/Documents/KBTU 2022/Data Visualization/for_final/python/fixing and convertation.ipynb Cell 5' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/home/kenu/Documents/KBTU%202022/Data%20Visualization/for_final/python/fixing%20and%20convertation.ipynb#ch0000004?line=0'>1</a> for column in df.columns:
# ----> <a href='vscode-notebook-cell:/home/kenu/Documents/KBTU%202022/Data%20Visualization/for_final/python/fixing%20and%20convertation.ipynb#ch0000004?line=1'>2</a>     df[column] = df[column].apply(lambda x: 0 if x == "-" else round(x, 2))
#       <a href='vscode-notebook-cell:/home/kenu/Documents/KBTU%202022/Data%20Visualization/for_final/python/fixing%20and%20convertation.ipynb#ch0000004?line=2'>3</a>     df[column] = df[column].apply(lambda x: round(x, 2))
# ...

# %%
# Out:
# RangeIndex(start=0, stop=19, step=1)

# %%
for column in df.columns:
    if str(df[column][0]).isdigit() or df[column][0]=="-":
        df[column] = df[column].apply(lambda x: 0 if x == "-" else round(x, 2))
    if str(df[column][0]).isdigit() or df[column][0]=="-":
        df[column] = df[column].apply(lambda x: round(x, 2))

df_t = df.T
try:
    df_t["Акмолинская"] = df_t["г. Астана"] + df_t["Акмолинская"]
except:
    pass
    # df_t["Акмолинская"] = df_t["г. Нур-Султан"] + df_t["Акмолинская"]
    

# df_t["Алматинская"] = df_t["г.Алматы"] + df_t["Алматинская"]
df_t["Алматинская"] = df_t["г.Алматы"] + df_t["Алматинская"]
# df_t["Туркестанская"] = df_t["г.Шымкент"] + df_t["Туркестанская"] + df_t["Южно-Казахстанская"]
df_t["Туркестанская"] = df_t["г. Шымкент"] + df_t["Туркестанская"] + df_t["Южно-Казахстанская"]


df = df_t.T
try:
    df = df.drop(labels=["г. Астана"], axis=0)
except:
    pass
    # df = df.drop(labels=["г. Нур-Султан"], axis=0)

    
# df = df.drop(labels=["г.Алматы", "г.Шымкент","Южно-Казахстанская"], axis=0)
df = df.drop(labels=["г. Алматы", "г. Шымкент","Южно-Казахстанская"], axis=0)


df_t = df.T
column_re = {'Республика Казахстан': 'Republic of Kazakhstan', 'Акмолинская': 'Aqmola',
                   "Актюбинская": "Aqtöbe", "Алматинская": "Almaty", "Атырауская": "Atyrau",
                   "Западно-Казахстанская": "West Kazakhstan", "Жамбылская": "Zhambyl",
                   "Карагандинская": "Qaraghandy", "Костанайская": "Qostanay", "Мангыстауская": "Mangghystau",
                   "Кызылординская": "Qyzylorda", "Туркестанская": "Türkistan",
                   "Павлодарская": "Pavlodar", "Северо-Казахстанская": "North Kazakhstan",
                   "Восточно-Казахстанская": "East Kazakhstan"}
df_t.rename(columns=column_re, inplace=True)
df=df_t.T
easy_data = pd.DataFrame(columns=["region", "product", "centner_hect", "year"])
product = "wheat"
for index in df.index:
    region = index
    for column in df.columns:
        # year
        year = column
        easy_data = easy_data.append({"region":region, "product":product, "thous_hect":df.loc[region, year], "year":year}, ignore_index=True)
        # easy_data["region"] = region
        # easy_data["product"] = product
        # easy_data["thous_hect"] = df.loc[region, year]
        # easy_data["year"] = year

easy_data.head()
easy_data.to_csv("real_gross_100_per_hect_wheat_rice_legumes.csv")

# /home/kenu/Documents/KBTU 2022/Data Visualization/for_final/final_data/real_gross_100_per_hect_wheat_rice_legumes.xlsx
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/kenu/Documents/KBTU 2022/Data Visualization/for_final/python/fixing and convertation.ipynb Cell 7' in <cell line: 16>()
#      <a href='vscode-notebook-cell:/home/kenu/Documents/KBTU%202022/Data%20Visualization/for_final/python/fixing%20and%20convertation.ipynb#ch0000005?line=10'>11</a>     pass
#      <a href='vscode-notebook-cell:/home/kenu/Documents/KBTU%202022/Data%20Visualization/for_final/python/fixing%20and%20convertation.ipynb#ch0000005?line=11'>12</a>     # df_t["Акмолинская"] = df_t["г. Нур-Султан"] + df_t["Акмолинская"]
#      <a href='vscode-notebook-cell:/home/kenu/Documents/KBTU%202022/Data%20Visualization/for_final/python/fixing%20and%20convertation.ipynb#ch0000005?line=12'>13</a>
# ...

# %%
import pandas as pd

df_total_area = pd.read_excel(
    "/home/kenu/Documents/KBTU 2022/Data Visualization/for_final/final_data/crop area_2004-2021_thou_hectare.xlsx")
df_cereals_rice_wheat_legumes = pd.read_excel(
    "/home/kenu/Documents/KBTU 2022/Data Visualization/for_final/final_data/acreage of cereals (including rice) and legumes_thou_hectare.xlsx")
df_oil = pd.read_excel(
    "/home/kenu/Documents/KBTU 2022/Data Visualization/for_final/final_data/acreage of oilseed crops_thou_hectare.xlsx")
df_sunflower= pd.read_excel(
    "/home/kenu/Documents/KBTU 2022/Data Visualization/for_final/final_data/acreage_sunflower seeds_thou_hectare.xlsx")
df_cotton= pd.read_excel(
    "/home/kenu/Documents/KBTU 2022/Data Visualization/for_final/final_data/cotton_2004-2021_thou_hectare.xlsx")
df_potato= pd.read_excel(
    "/home/kenu/Documents/KBTU 2022/Data Visualization/for_final/final_data/potato acreage_thou_hectare.xlsx")
df_sugar= pd.read_excel(
    "/home/kenu/Documents/KBTU 2022/Data Visualization/for_final/final_data/sugar beet_2004-2021_thou_hectare.xlsx")
df_vegatable = pd.read_excel(
    "/home/kenu/Documents/KBTU 2022/Data Visualization/for_final/final_data/vegetables-ground_2004-2021_thou_hectare.xlsx")
df_sugar= pd.read_excel(
    "/home/kenu/Documents/KBTU 2022/Data Visualization/for_final/final_data/sugar beet_2004-2021_thou_hectare.xlsx")

# %%
path = "/home/kenu/Documents/KBTU 2022/Data Visualization/for_final/data/2_Валовый_выпуск_сх_1999_2020_категории_хозяйств.xlsx"
df = pd.read_excel(path)
print(df.head())

print(df.columns)
for column in df.columns:
    if str(df[column][0]).isdigit() or df[column][0]=="-":
        df[column] = df[column].apply(lambda x: 0 if x == "-" else round(x, 2))
    if str(df[column][0]).isdigit() or df[column][0]=="-":
        df[column] = df[column].apply(lambda x: round(x, 2))

df_t = df.T

print(df_t.head())

# try:
# df_t["Акмолинская"] = df_t["г. Астана"] + df_t["Акмолинская"]
# # except:
# #     df_t["Акмолинская"] = df_t["г. Нур-Султан"] + df_t["Акмолинская"]
    

# # df_t["Алматинская"] = df_t["г.Алматы"] + df_t["Алматинская"]
# df_t["Алматинская"] = df_t["г. Алматы"] + df_t["Алматинская"]
# # df_t["Туркестанская"] = df_t["г.Шымкент"] + df_t["Туркестанская"] + df_t["Южно-Казахстанская"]
# df_t["Туркестанская"] = df_t["г. Шымкент"] + df_t["Туркестанская"] + df_t["Южно-Казахстанская"]



# try:
#     df = df.drop(labels=["г. Астана"], axis=0)
# except:
#     pass
    # df = df.drop(labels=["г. Нур-Султан"], axis=0)

    
# df = df.drop(labels=["г.Алматы", "г.Шымкент","Южно-Казахстанская"], axis=0)
# df = df.drop(labels=["г. Алматы", "г. Шымкент","Южно-Казахстанская"], axis=0)



column_re = {'Республика Казахстан': 'Republic of Kazakhstan', 'Акмолинская': 'Aqmola',
                   "Актюбинская": "Aqtöbe", "Алматинская": "Almaty", "Атырауская": "Atyrau",
                   "Западно-Казахстанская": "West Kazakhstan", "Жамбылская": "Zhambyl",
                   "Карагандинская": "Qaraghandy", "Костанайская": "Qostanay", "Мангыстауская": "Mangghystau",
                   "Кызылординская": "Qyzylorda", "Туркестанская": "Türkistan",
                   "Павлодарская": "Pavlodar", "Северо-Казахстанская": "North Kazakhstan",
                   "Восточно-Казахстанская": "East Kazakhstan"}

df_t.rename(columns=column_re, inplace=True)
# Out:
#                  region      1999       2000       2001       2002       2003  \
# 0  Республика Казахстан  98,709.8  101,097.1  144,137.8  123,583.5  140,146.2
# 1           Акмолинская  23,935.0   23,699.3   39,010.4   29,458.1   34,511.9
# 2           Актюбинская   3,680.4    4,427.7    5,154.7    3,936.1    5,182.0
# 3           Алматинская   8,170.2    5,529.4    5,632.6    9,762.8   11,068.2
# 4            Атырауская     376.5      341.7      399.0      375.9      433.3
#
#         2004       2005       2006       2007  ...       2011       2012  \
# 0  168,362.2  174,036.7  187,929.8  291,078.0  ...  682,886.9  396,032.6
# 1   38,677.4   36,266.8   36,306.9   64,552.3  ...  151,386.4   68,082.6
# 2    5,169.7    4,356.2    2,986.2    7,124.1  ...   14,413.4   10,335.3
# 3   14,314.4   16,056.6   17,410.3   21,044.7  ...   41,050.7   46,246.4
# 4      400.9      522.6      571.8      720.4  ...    1,373.3    1,544.2
#
# ...

# %%
column_re = {'Республика Казахстан': 'Republic of Kazakhstan', 'Акмолинская': 'Aqmola',
                   "Актюбинская": "Aqtöbe", "Алматинская": "Almaty", "Атырауская": "Atyrau",
                   "Западно-Казахстанская": "West Kazakhstan", "Жамбылская": "Zhambyl",
                   "Карагандинская": "Qaraghandy", "Костанайская": "Qostanay", "Мангыстауская": "Mangghystau",
                   "Кызылординская": "Qyzylorda", "Туркестанская": "Türkistan",
                   "Павлодарская": "Pavlodar", "Северо-Казахстанская": "North Kazakhstan",
                   "Восточно-Казахстанская": "East Kazakhstan"}

df.rename(columns=column_re, inplace=True)

# %%
easy_data.T.rename(index=column_re, inplace=True)
easy_data.to_csv("crop.csv", index_label=False)

# %%
df = df.set_index("region")

# %%
easy_data = pd.DataFrame(columns=["region", "product", "centner_hect", "year"])
product = "wheat"
for index in df.index:
    region = index
    for column in df.columns:
        # year
        year = column
        print({"region":region, "product":product, "thous_hect":df.loc[region, year], "year":year})
        easy_data = easy_data.append({"region":region, "product":product, "thous_hect":df.loc[region, year], "year":year}, ignore_index=True)
        # easy_data["region"] = region
        # easy_data["product"] = product
        # easy_data["thous_hect"] = df.loc[region, year]
        # easy_data["year"] = year

easy_data.head()
easy_data.to_csv("crop.csv")

# /home/kenu/Documents/KBTU 2022/Data Visualization/for_final/final_data/real_gross_100_per_hect_wheat_rice_legumes.xlsx
# Out:
# {'region': 'Республика Казахстан', 'product': 'wheat', 'thous_hect': '98,709.8', 'year': '1999'}
# {'region': 'Республика Казахстан', 'product': 'wheat', 'thous_hect': '101,097.1', 'year': '2000'}
# {'region': 'Республика Казахстан', 'product': 'wheat', 'thous_hect': '144,137.8', 'year': '2001'}
# {'region': 'Республика Казахстан', 'product': 'wheat', 'thous_hect': '123,583.5', 'year': '2002'}
# {'region': 'Республика Казахстан', 'product': 'wheat', 'thous_hect': '140,146.2', 'year': '2003'}
# {'region': 'Республика Казахстан', 'product': 'wheat', 'thous_hect': '168,362.2', 'year': '2004'}
# {'region': 'Республика Казахстан', 'product': 'wheat', 'thous_hect': '174,036.7', 'year': '2005'}
# {'region': 'Республика Казахстан', 'product': 'wheat', 'thous_hect': '187,929.8', 'year': '2006'}
# {'region': 'Республика Казахстан', 'product': 'wheat', 'thous_hect': '291,078.0', 'year': '2007'}
# {'region': 'Республика Казахстан', 'product': 'wheat', 'thous_hect': '364,034.0', 'year': '2008'}
# ...

# %%
easy_data.to_csv("crop.csv")
